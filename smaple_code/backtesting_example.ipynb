# %%
import backtesting_framework as bf
import momentum_strategy
import pandas as pd
import datetime

# %% [markdown]
# ### 讀取資料

# %%
datas_table = pd.read_csv('(2010-2021)stock_price.csv', index_col=0, header=[0,1], parse_dates=True)
datas_table.head(2)
# Out:
#            AAPL US Equity                                              \
#                     CLOSE      HIGH       LOW      OPEN        VOLUME
# 2010-01-04       7.649278  7.660707  7.586421  7.626778  1.525399e+08
# 2010-01-05       7.656421  7.699635  7.616421  7.671064  1.704628e+08
#
#            NFLX US Equity                                              ...  \
#                     CLOSE      HIGH       LOW      OPEN        VOLUME  ...
# 2010-01-04       7.639992  7.944278  7.565707  7.887135  6.048363e+06  ...
# 2010-01-05       7.358564  7.652849  7.258564  7.652849  6.669432e+06  ...
#
#            GE US Equity                                                 \
#                   CLOSE        HIGH         LOW        OPEN     VOLUME
# 2010-01-04   118.810624  120.271725  116.503621  116.965022  1736937.5
# 2010-01-05   119.425824  120.425525  118.810624  118.810624  1476875.0
#
#            OXY US Equity
#                    CLOSE       HIGH        LOW       OPEN     VOLUME
# 2010-01-04     79.711135  80.085231  78.847838  79.202749  1035600.0
# 2010-01-05     79.135604  79.835834  78.684771  79.711135  1034400.0
#
# [2 rows x 25 columns]

# %% [markdown]
# ### 回測

# %%
# 參數設定
formation_period=20  # 用20個交易日計算動能
stocks_number=2      # 每次rebalance買進兩支股票
reserve_ratio=0.05   # 每次rebalance保留5%現金
strategy_execute_start_date = datetime.datetime(2019,12,31) # 策略執行日


#回測
cerebro = bf.cerebro.Cerebro()
cerebro.datas_table = datas_table
cerebro.addstrategy(
    momentum_strategy.Strategy,
    formation_period=formation_period,
    stocks_number=stocks_number,
    reserve_ratio=reserve_ratio
)
cerebro.notify_orNot = True
cerebro.close_at_BacktestingEndDate_orNot = True
cerebro.cash = 100000

cerebro.start_date = datetime.datetime(2019,12,1)
cerebro.strategy_execute_start_date = strategy_execute_start_date
cerebro.end_date = datetime.datetime(2021,12,31)

cerebro.run()
# Out:
# AMD US Equity - rank:1 - momentum_value:0.18409501678285567
# AAPL US Equity - rank:2 - momentum_value:0.11163688673531169
# ---after_next---
# pending_open_orders=['AMD US Equity', 'AAPL US Equity']
# pending_close_orders=[]
# holded_orders=[]
#
#
#
# 2020-01-02 00:00:00 success(open) -- magic number=1 ,  AAPL US Equity , size=647 , value=47921.6725 , executed_price=74.0675
# 2020-01-02 00:00:00 success(open) -- magic number=2 ,  AMD US Equity , size=1035 , value=48541.5 , executed_price=46.9
# NFLX US Equity - rank:1 - momentum_value:0.046329704981656006
# GE US Equity - rank:2 - momentum_value:0.043587594300083854
# ---after_next---
# pending_open_orders=['NFLX US Equity', 'GE US Equity']
# pending_close_orders=['AAPL US Equity', 'AMD US Equity']
# holded_orders=['AAPL US Equity', 'AMD US Equity']
#
#
#
# 2020-02-03 00:00:00 success(close) -- magic number=1 , AAPL US Equity , size=647, value=49189.7925 , close_price=76.0275
# 2020-02-03 00:00:00 success(close) -- magic number=2 , AMD US Equity , size=1035, value=48024.0 , close_price=46.4
# 2020-02-03 00:00:00 success(open) -- magic number=3 ,  GE US Equity , size=487 , value=48583.12 , executed_price=99.76
# 2020-02-03 00:00:00 success(open) -- magic number=4 ,  NFLX US Equity , size=140 , value=48613.6 , executed_price=347.24
# NFLX US Equity - rank:1 - momentum_value:0.06122390291597157
# AMD US Equity - rank:2 - momentum_value:-0.06765067650676515
# ---after_next---
# pending_open_orders=['NFLX US Equity', 'AMD US Equity']
# pending_close_orders=['GE US Equity']
# holded_orders=['GE US Equity', 'NFLX US Equity']
#
#
#
# 2020-03-02 00:00:00 success(close) -- magic number=3 , GE US Equity , size=487, value=43479.36 , close_price=89.28
# 2020-03-02 00:00:00 success(open) -- magic number=5 ,  NFLX US Equity , size=-14 , value=-5223.54 , executed_price=373.11
# 2020-03-02 00:00:00 success(open) -- magic number=6 ,  AMD US Equity , size=1019 , value=48310.78999999999 , executed_price=47.41
# NFLX US Equity - rank:1 - momentum_value:0.018249857634840216
# AMD US Equity - rank:2 - momentum_value:-0.02716577540106957
# ---after_next---
# pending_open_orders=['NFLX US Equity', 'AMD US Equity']
# pending_close_orders=[]
# holded_orders=['NFLX US Equity', 'NFLX US Equity', 'AMD US Equity']
#
#
#
# 2020-04-01 00:00:00 success(open) -- magic number=7 ,  NFLX US Equity , size=-2 , value=-751.0 , executed_price=375.5
# 2020-04-01 00:00:00 success(open) -- magic number=8 ,  AMD US Equity , size=0 , value=0.0 , executed_price=44.26
# OXY US Equity - rank:1 - momentum_value:0.5456238361266295
# AAPL US Equity - rank:2 - momentum_value:0.21954256776389536
# ---after_next---
# pending_open_orders=['OXY US Equity', 'AAPL US Equity']
# pending_close_orders=['NFLX US Equity', 'NFLX US Equity', 'AMD US Equity', 'NFLX US Equity', 'AMD US Equity']
# holded_orders=['NFLX US Equity', 'NFLX US Equity', 'AMD US Equity', 'NFLX US Equity', 'AMD US Equity']
#
#
#
# 2020-05-01 00:00:00 success(close) -- magic number=4 , NFLX US Equity , size=140, value=58114.0 , close_price=415.1
# 2020-05-01 00:00:00 success(close) -- magic number=6 , AMD US Equity , size=1019, value=51999.57 , close_price=51.03
# 2020-05-01 00:00:00 success(close) -- magic number=8 , AMD US Equity , size=0, value=0.0 , close_price=51.03
# 2020-05-01 00:00:00 success(close) -- magic number=7 , NFLX US Equity , size=-2, value=-830.2 , close_price=415.1
# 2020-05-01 00:00:00 success(close) -- magic number=5 , NFLX US Equity , size=-14, value=-5811.400000000001 , close_price=415.1
# 2020-05-01 00:00:00 success(open) -- magic number=9 ,  OXY US Equity , size=3151 , value=50479.02 , executed_price=16.02
# 2020-05-01 00:00:00 success(open) -- magic number=10 ,  AAPL US Equity , size=712 , value=50925.8 , executed_price=71.525
# AAPL US Equity - rank:1 - momentum_value:0.08216473791695034
# AMD US Equity - rank:2 - momentum_value:0.02691353311700695
# ---after_next---
# pending_open_orders=['AAPL US Equity', 'AMD US Equity']
# pending_close_orders=['OXY US Equity']
# holded_orders=['OXY US Equity', 'AAPL US Equity']
#
#
#
# 2020-06-01 00:00:00 success(close) -- magic number=9 , OXY US Equity , size=3151, value=40584.880000000005 , close_price=12.88
# 2020-06-01 00:00:00 success(open) -- magic number=11 ,  AAPL US Equity , size=-89 , value=-7071.7175 , executed_price=79.4575
# 2020-06-01 00:00:00 success(open) -- magic number=12 ,  AMD US Equity , size=919 , value=48982.7 , executed_price=53.3
# OXY US Equity - rank:1 - momentum_value:0.2406779661016949
# AAPL US Equity - rank:2 - momentum_value:0.12822416032659123
# ---after_next---
# pending_open_orders=['OXY US Equity', 'AAPL US Equity']
# pending_close_orders=['AMD US Equity']
# holded_orders=['AAPL US Equity', 'AAPL US Equity', 'AMD US Equity']
#
#
#
# 2020-07-01 00:00:00 success(close) -- magic number=12 , AMD US Equity , size=919, value=48366.97 , close_price=52.63
# 2020-07-01 00:00:00 success(open) -- magic number=13 ,  AAPL US Equity , size=-46 , value=-4197.615 , executed_price=91.2525
# 2020-07-01 00:00:00 success(open) -- magic number=14 ,  OXY US Equity , size=2870 , value=52578.4 , executed_price=18.32
# AMD US Equity - rank:1 - momentum_value:0.4793656858998854
# AAPL US Equity - rank:2 - momentum_value:0.16733954024882602
# ---after_next---
# pending_open_orders=['AMD US Equity', 'AAPL US Equity']
# pending_close_orders=['OXY US Equity']
# holded_orders=['AAPL US Equity', 'AAPL US Equity', 'AAPL US Equity', 'OXY US Equity']
#
#
#
# 2020-08-03 00:00:00 success(close) -- magic number=14 , OXY US Equity , size=2870, value=45145.1 , close_price=15.73
# 2020-08-03 00:00:00 success(open) -- magic number=15 ,  AAPL US Equity , size=-76 , value=-8227.0 , executed_price=108.25
# 2020-08-03 00:00:00 success(open) -- magic number=16 ,  AMD US Equity , size=686 , value=53638.34 , executed_price=78.19
# AAPL US Equity - rank:1 - momentum_value:0.1845324153757888
# AMD US Equity - rank:2 - momentum_value:0.16930603836745184
# ---after_next---
# pending_open_orders=['AAPL US Equity', 'AMD US Equity']
# pending_close_orders=[]
# holded_orders=['AAPL US Equity', 'AAPL US Equity', 'AAPL US Equity', 'AAPL US Equity', 'AMD US Equity']
#
#
#
# 2020-09-01 00:00:00 success(open) -- magic number=17 ,  AAPL US Equity , size=-14 , value=-1860.74 , executed_price=132.91
# 2020-09-01 00:00:00 success(open) -- magic number=18 ,  AMD US Equity , size=4 , value=368.08 , executed_price=92.02
# GE US Equity - rank:1 - momentum_value:0.00646203554119551
# NFLX US Equity - rank:2 - momentum_value:-0.10155421794986974
# ---after_next---
# pending_open_orders=['GE US Equity', 'NFLX US Equity']
# pending_close_orders=['AAPL US Equity', 'AAPL US Equity', 'AAPL US Equity', 'AAPL US Equity', 'AMD US Equity', 'AAPL US Equity', 'AMD US Equity']
# holded_orders=['AAPL US Equity', 'AAPL US Equity', 'AAPL US Equity', 'AAPL US Equity', 'AMD US Equity', 'AAPL US Equity', 'AMD US Equity']
#
#
#
# 2020-10-01 00:00:00 success(close) -- magic number=10 , AAPL US Equity , size=712, value=83816.64 , close_price=117.72
# 2020-10-01 00:00:00 success(close) -- magic number=16 , AMD US Equity , size=686, value=57013.46 , close_price=83.11
# 2020-10-01 00:00:00 success(close) -- magic number=18 , AMD US Equity , size=4, value=332.44 , close_price=83.11
# 2020-10-01 00:00:00 success(close) -- magic number=17 , AAPL US Equity , size=-14, value=-1648.08 , close_price=117.72
# 2020-10-01 00:00:00 success(close) -- magic number=13 , AAPL US Equity , size=-46, value=-5415.12 , close_price=117.72
# 2020-10-01 00:00:00 success(close) -- magic number=15 , AAPL US Equity , size=-76, value=-8946.72 , close_price=117.72
# 2020-10-01 00:00:00 success(close) -- magic number=11 , AAPL US Equity , size=-89, value=-10477.08 , close_price=117.72
# 2020-10-01 00:00:00 success(open) -- magic number=19 ,  GE US Equity , size=1140 , value=57273.600000000006 , executed_price=50.24
# 2020-10-01 00:00:00 success(open) -- magic number=20 ,  NFLX US Equity , size=113 , value=57228.85 , executed_price=506.45
# GE US Equity - rank:1 - momentum_value:0.16118935837245707
# AAPL US Equity - rank:2 - momentum_value:-0.03680764466466113
# ---after_next---
# pending_open_orders=['GE US Equity', 'AAPL US Equity']
# pending_close_orders=['NFLX US Equity']
# holded_orders=['GE US Equity', 'NFLX US Equity']
#
#
#
# 2020-11-02 00:00:00 success(close) -- magic number=20 , NFLX US Equity , size=113, value=54114.57 , close_price=478.89
# 2020-11-02 00:00:00 success(open) -- magic number=21 ,  GE US Equity , size=-113 , value=-6770.96 , executed_price=59.92
# 2020-11-02 00:00:00 success(open) -- magic number=22 ,  AAPL US Equity , size=559 , value=61065.159999999996 , executed_price=109.24
# OXY US Equity - rank:1 - momentum_value:0.7261774370208103
# GE US Equity - rank:2 - momentum_value:0.37196765498652296
# ---after_next---
# pending_open_orders=['OXY US Equity', 'GE US Equity']
# pending_close_orders=['AAPL US Equity']
# holded_orders=['GE US Equity', 'GE US Equity', 'AAPL US Equity']
#
#
#
# 2020-12-01 00:00:00 success(close) -- magic number=22 , AAPL US Equity , size=559, value=67661.36 , close_price=121.04
# 2020-12-01 00:00:00 success(open) -- magic number=23 ,  GE US Equity , size=-112 , value=-9273.6 , executed_price=82.8
# 2020-12-01 00:00:00 success(open) -- magic number=24 ,  OXY US Equity , size=4726 , value=75048.88 , executed_price=15.88
# OXY US Equity - rank:1 - momentum_value:0.08936438011327863
# AAPL US Equity - rank:2 - momentum_value:0.07807929801754954
# ---after_next---
# pending_open_orders=['OXY US Equity', 'AAPL US Equity']
# pending_close_orders=['GE US Equity', 'GE US Equity', 'GE US Equity']
# holded_orders=['GE US Equity', 'GE US Equity', 'GE US Equity', 'OXY US Equity']
#
#
#
# 2021-01-04 00:00:00 success(close) -- magic number=19 , GE US Equity , size=1140, value=99408.0 , close_price=87.2
# 2021-01-04 00:00:00 success(close) -- magic number=23 , GE US Equity , size=-112, value=-9766.4 , close_price=87.2
# 2021-01-04 00:00:00 success(close) -- magic number=21 , GE US Equity , size=-113, value=-9853.6 , close_price=87.2
# 2021-01-04 00:00:00 success(open) -- magic number=25 ,  OXY US Equity , size=-77 , value=-1361.36 , executed_price=17.68
# 2021-01-04 00:00:00 success(open) -- magic number=26 ,  AAPL US Equity , size=606 , value=80937.36 , executed_price=133.56
# OXY US Equity - rank:1 - momentum_value:0.12004466778336109
# NFLX US Equity - rank:2 - momentum_value:0.014868754646485849
# ---after_next---
# pending_open_orders=['OXY US Equity', 'NFLX US Equity']
# pending_close_orders=['AAPL US Equity']
# holded_orders=['OXY US Equity', 'OXY US Equity', 'AAPL US Equity']
#
#
#
# 2021-02-01 00:00:00 success(close) -- magic number=26 , AAPL US Equity , size=606, value=80991.90000000001 , close_price=133.65
# 2021-02-01 00:00:00 success(open) -- magic number=27 ,  OXY US Equity , size=-340 , value=-6976.8 , executed_price=20.52
# 2021-02-01 00:00:00 success(open) -- magic number=28 ,  NFLX US Equity , size=162 , value=86989.14 , executed_price=536.97
# OXY US Equity - rank:1 - momentum_value:0.27016706443914074
# GE US Equity - rank:2 - momentum_value:0.13074842200180337
# ---after_next---
# pending_open_orders=['OXY US Equity', 'GE US Equity']
# pending_close_orders=['NFLX US Equity']
# holded_orders=['OXY US Equity', 'OXY US Equity', 'OXY US Equity', 'NFLX US Equity']
#
#
#
# 2021-03-01 00:00:00 success(close) -- magic number=28 , NFLX US Equity , size=162, value=88463.34000000001 , close_price=546.07
# 2021-03-01 00:00:00 success(open) -- magic number=29 ,  OXY US Equity , size=-530 , value=-14506.1 , executed_price=27.37
# 2021-03-01 00:00:00 success(open) -- magic number=30 ,  GE US Equity , size=1002 , value=103646.88 , executed_price=103.44
# NFLX US Equity - rank:1 - momentum_value:0.0018436719800267731
# AAPL US Equity - rank:2 - momentum_value:0.0007373422906766791
# ---after_next---
# pending_open_orders=['NFLX US Equity', 'AAPL US Equity']
# pending_close_orders=['OXY US Equity', 'OXY US Equity', 'OXY US Equity', 'OXY US Equity', 'GE US Equity']
# holded_orders=['OXY US Equity', 'OXY US Equity', 'OXY US Equity', 'OXY US Equity', 'GE US Equity']
#
#
#
# 2021-04-01 00:00:00 success(close) -- magic number=24 , OXY US Equity , size=4726, value=126940.36 , close_price=26.86
# 2021-04-01 00:00:00 success(close) -- magic number=30 , GE US Equity , size=1002, value=106051.68000000001 , close_price=105.84
# 2021-04-01 00:00:00 success(close) -- magic number=25 , OXY US Equity , size=-77, value=-2068.22 , close_price=26.86
# 2021-04-01 00:00:00 success(close) -- magic number=27 , OXY US Equity , size=-340, value=-9132.4 , close_price=26.86
# 2021-04-01 00:00:00 success(close) -- magic number=29 , OXY US Equity , size=-530, value=-14235.8 , close_price=26.86
# 2021-04-01 00:00:00 success(open) -- magic number=31 ,  AAPL US Equity , size=835 , value=103247.75 , executed_price=123.65
# 2021-04-01 00:00:00 success(open) -- magic number=32 ,  NFLX US Equity , size=195 , value=103346.1 , executed_price=529.98
# AAPL US Equity - rank:1 - momentum_value:0.06878048780487811
# AMD US Equity - rank:2 - momentum_value:0.006535947712418277
# ---after_next---
# pending_open_orders=['AAPL US Equity', 'AMD US Equity']
# pending_close_orders=['NFLX US Equity']
# holded_orders=['AAPL US Equity', 'NFLX US Equity']
#
#
#
# 2021-05-03 00:00:00 success(close) -- magic number=32 , NFLX US Equity , size=195, value=99966.75 , close_price=512.65
# 2021-05-03 00:00:00 success(open) -- magic number=33 ,  AAPL US Equity , size=-40 , value=-5280.4 , executed_price=132.01
# 2021-05-03 00:00:00 success(open) -- magic number=34 ,  AMD US Equity , size=1279 , value=104839.63 , executed_price=81.97
# GE US Equity - rank:1 - momentum_value:0.07164634146341475
# OXY US Equity - rank:2 - momentum_value:0.023659305993690927
# ---after_next---
# pending_open_orders=['GE US Equity', 'OXY US Equity']
# pending_close_orders=['AAPL US Equity', 'AAPL US Equity', 'AMD US Equity']
# holded_orders=['AAPL US Equity', 'AAPL US Equity', 'AMD US Equity']
#
#
#
# 2021-06-01 00:00:00 success(close) -- magic number=31 , AAPL US Equity , size=835, value=104500.25 , close_price=125.15
# 2021-06-01 00:00:00 success(close) -- magic number=34 , AMD US Equity , size=1279, value=103599.0 , close_price=81.0
# 2021-06-01 00:00:00 success(close) -- magic number=33 , AAPL US Equity , size=-40, value=-5006.0 , close_price=125.15
# 2021-06-01 00:00:00 success(open) -- magic number=35 ,  GE US Equity , size=894 , value=101772.96 , executed_price=113.84
# 2021-06-01 00:00:00 success(open) -- magic number=36 ,  OXY US Equity , size=3877 , value=103670.98 , executed_price=26.74
# AMD US Equity - rank:1 - momentum_value:0.14590703916066872
# AAPL US Equity - rank:2 - momentum_value:0.09515432592355677
# ---after_next---
# pending_open_orders=['AMD US Equity', 'AAPL US Equity']
# pending_close_orders=['GE US Equity', 'OXY US Equity']
# holded_orders=['GE US Equity', 'OXY US Equity']
#
#
#
# 2021-07-01 00:00:00 success(close) -- magic number=36 , OXY US Equity , size=3877, value=127553.29999999999 , close_price=32.9
# 2021-07-01 00:00:00 success(close) -- magic number=35 , GE US Equity , size=894, value=97052.64 , close_price=108.56
# 2021-07-01 00:00:00 success(open) -- magic number=37 ,  AMD US Equity , size=1140 , value=107103.0 , executed_price=93.95
# 2021-07-01 00:00:00 success(open) -- magic number=38 ,  AAPL US Equity , size=782 , value=106750.81999999999 , executed_price=136.51
# AMD US Equity - rank:1 - momentum_value:0.13803450862715683
# AAPL US Equity - rank:2 - momentum_value:0.06257740220004382
# ---after_next---
# pending_open_orders=['AMD US Equity', 'AAPL US Equity']
# pending_close_orders=[]
# holded_orders=['AMD US Equity', 'AAPL US Equity']
#
#
#
# 2021-08-02 00:00:00 success(open) -- magic number=39 ,  AMD US Equity , size=-4 , value=-423.44 , executed_price=105.86
# 2021-08-02 00:00:00 success(open) -- magic number=40 ,  AAPL US Equity , size=44 , value=6438.52 , executed_price=146.33
# NFLX US Equity - rank:1 - momentum_value:0.11426725656787129
# AAPL US Equity - rank:2 - momentum_value:0.030333876221498413
# ---after_next---
# pending_open_orders=['NFLX US Equity', 'AAPL US Equity']
# pending_close_orders=['AMD US Equity', 'AMD US Equity']
# holded_orders=['AMD US Equity', 'AAPL US Equity', 'AMD US Equity', 'AAPL US Equity']
#
#
#
# 2021-09-01 00:00:00 success(close) -- magic number=37 , AMD US Equity , size=1140, value=126904.79999999999 , close_price=111.32
# 2021-09-01 00:00:00 success(close) -- magic number=39 , AMD US Equity , size=-4, value=-445.28 , close_price=111.32
# 2021-09-01 00:00:00 success(open) -- magic number=41 ,  AAPL US Equity , size=0 , value=0.0 , executed_price=152.82
# 2021-09-01 00:00:00 success(open) -- magic number=42 ,  NFLX US Equity , size=220 , value=125180.0 , executed_price=569.0
# OXY US Equity - rank:1 - momentum_value:0.17942583732057416
# NFLX US Equity - rank:2 - momentum_value:0.04856804164447581
# ---after_next---
# pending_open_orders=['OXY US Equity', 'NFLX US Equity']
# pending_close_orders=['AAPL US Equity', 'AAPL US Equity', 'AAPL US Equity']
# holded_orders=['AAPL US Equity', 'AAPL US Equity', 'AAPL US Equity', 'NFLX US Equity']
#
#
#
# 2021-10-01 00:00:00 success(close) -- magic number=38 , AAPL US Equity , size=782, value=110887.6 , close_price=141.8
# 2021-10-01 00:00:00 success(close) -- magic number=40 , AAPL US Equity , size=44, value=6239.200000000001 , close_price=141.8
# 2021-10-01 00:00:00 success(close) -- magic number=41 , AAPL US Equity , size=0, value=0.0 , close_price=141.8
# 2021-10-01 00:00:00 success(open) -- magic number=43 ,  NFLX US Equity , size=-13 , value=-7861.360000000001 , executed_price=604.72
# 2021-10-01 00:00:00 success(open) -- magic number=44 ,  OXY US Equity , size=4259 , value=127003.38 , executed_price=29.82
# AMD US Equity - rank:1 - momentum_value:0.17354807223035618
# NFLX US Equity - rank:2 - momentum_value:0.12584196363043287
# ---after_next---
# pending_open_orders=['AMD US Equity', 'NFLX US Equity']
# pending_close_orders=['OXY US Equity']
# holded_orders=['NFLX US Equity', 'NFLX US Equity', 'OXY US Equity']
#
#
#
# 2021-11-01 00:00:00 success(close) -- magic number=44 , OXY US Equity , size=4259, value=146168.88 , close_price=34.32
# 2021-11-01 00:00:00 success(open) -- magic number=45 ,  NFLX US Equity , size=-2 , value=-1378.12 , executed_price=689.06
# 2021-11-01 00:00:00 success(open) -- magic number=46 ,  AMD US Equity , size=1176 , value=140473.2 , executed_price=119.45
# AMD US Equity - rank:1 - momentum_value:0.26463307514173917
# AAPL US Equity - rank:2 - momentum_value:0.10969387755102034
# ---after_next---
# pending_open_orders=['AMD US Equity', 'AAPL US Equity']
# pending_close_orders=['NFLX US Equity', 'NFLX US Equity', 'NFLX US Equity']
# holded_orders=['NFLX US Equity', 'NFLX US Equity', 'NFLX US Equity', 'AMD US Equity']
#
#
#
# 2021-12-01 00:00:00 success(close) -- magic number=42 , NFLX US Equity , size=220, value=142885.6 , close_price=649.48
# 2021-12-01 00:00:00 success(close) -- magic number=45 , NFLX US Equity , size=-2, value=-1298.96 , close_price=649.48
# 2021-12-01 00:00:00 success(close) -- magic number=43 , NFLX US Equity , size=-13, value=-8443.24 , close_price=649.48
# 2021-12-01 00:00:00 success(open) -- magic number=47 ,  AMD US Equity , size=-165 , value=-26461.05 , executed_price=160.37
# 2021-12-01 00:00:00 success(open) -- magic number=48 ,  AAPL US Equity , size=968 , value=162120.63999999998 , executed_price=167.48
# ---after_next---
# pending_open_orders=[]
# pending_close_orders=['AMD US Equity', 'AMD US Equity', 'AAPL US Equity']
# holded_orders=['AMD US Equity', 'AMD US Equity', 'AAPL US Equity']
#
#
#
# 2021-12-31 00:00:00 success(close) -- magic number=48 , AAPL US Equity , size=968, value=172386.28 , close_price=178.085
# 2021-12-31 00:00:00 success(close) -- magic number=46 , AMD US Equity , size=1176, value=171884.16 , close_price=146.16
# 2021-12-31 00:00:00 success(close) -- magic number=47 , AMD US Equity , size=-165, value=-24116.399999999998 , close_price=146.16
# AAPL US Equity - rank:1 - momentum_value:0.08433072789447982
# GE US Equity - rank:2 - momentum_value:-0.007980678357660476
# ---after_next---
# pending_open_orders=['AAPL US Equity', 'GE US Equity']
# pending_close_orders=[]
# holded_orders=[]

# %% [markdown]
# ### 策略價值走勢圖(剩餘現今走勢圖)

# %%
cerebro.analysis_obj.account_timeseries_state.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 所有曾買進的股票對於策略的貢獻

# %%
cerebro.analysis_obj.plot_the_contribution_of_individual_tickers()

# %% [markdown]
# ### 策略日報酬

# %%
cerebro.analysis_obj.strategy_daily_return().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 策略滾動(月)波動度

# %%
cerebro.analysis_obj.strategy_daily_return().rolling(20).std().plot()
# Out:
# <AxesSubplot:>
